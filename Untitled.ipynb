# %%
remove.packages("openmeteoR")

devtools::install_github(
  "spandandey12/Data534_project/openmeteoR",
  ref = "Rex2"
)

library(openmeteoR)
# Out:
# Removing package from ‘/Library/Frameworks/R.framework/Versions/4.5-arm64/Resources/library’
# (as ‘lib’ is unspecified)
#
# Using GitHub PAT from the git credential store.
#
# Downloading GitHub repo spandandey12/Data534_project@Rex2
# ── R CMD build ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ✔  checking for file ‘/private/var/folders/cs/dvv9sn7d043_8qlc0cn05vsh0000gn/T/RtmpK0eNrM/remotes1180815064c30/spandandey12-Data534_project-2811837/openmeteoR/DESCRIPTION’
# ─  preparing ‘openmeteoR’:
# ✔  checking DESCRIPTION meta-information
# ─  checking for LF line-endings in source and make files and shell scripts
# ─  checking for empty or unneeded directories
#    Omitted ‘LazyData’ from DESCRIPTION
# ─  building ‘openmeteoR_0.1.0.tar.gz’

# %%
ls("package:openmeteoR")
# Out:
# [1] "forecast_mountains"    "get_forecast"          "get_nearest_mountains"

# %%
sessionInfo()
# Out:
# R version 4.5.1 (2025-06-13)
# Platform: aarch64-apple-darwin20
# Running under: macOS Sequoia 15.3.1
#
# Matrix products: default
# BLAS:   /Library/Frameworks/R.framework/Versions/4.5-arm64/Resources/lib/libRblas.0.dylib
# LAPACK: /Library/Frameworks/R.framework/Versions/4.5-arm64/Resources/lib/libRlapack.dylib;  LAPACK version 3.12.1
#
# locale:
# [1] en_CA.UTF-8/en_CA.UTF-8/en_CA.UTF-8/C/en_CA.UTF-8/en_CA.UTF-8
#
# time zone: America/Vancouver
# tzcode source: internal
#
# attached base packages:
# [1] stats     graphics  grDevices utils     datasets  methods   base
#
# other attached packages:
# [1] openmeteoR_0.1.0
#
# loaded via a namespace (and not attached):
#  [1] crayon_1.5.3      vctrs_0.7.1       cli_3.6.5         rlang_1.1.7
#  [5] processx_3.8.6    purrr_1.1.0       pkgload_1.4.1     textshaping_1.0.1
#  [9] jsonlite_2.0.0    glue_1.8.0        htmltools_0.5.8.1 IRdisplay_1.1
# [13] ps_1.9.1          pkgbuild_1.4.8    IRkernel_1.3.2    ragg_1.4.0
# [17] evaluate_1.0.5    ellipsis_0.3.2    fastmap_1.2.0     base64enc_0.1-3
# [21] lifecycle_1.0.5   memoise_2.0.1     compiler_4.5.1    sessioninfo_1.2.3
# [25] fs_1.6.6          systemfonts_1.2.3 pbdZMQ_0.3-14     digest_0.6.37
# [29] R6_2.6.1          repr_1.1.7        usethis_3.2.1     pillar_1.11.1
# [33] curl_7.0.0        callr_3.7.6       magrittr_2.0.4    uuid_1.2-1
# [37] tools_4.5.1       devtools_2.4.6    desc_1.4.3        remotes_2.5.0
# [41] cachem_1.1.0
