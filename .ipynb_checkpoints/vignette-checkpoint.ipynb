# %%
# Determine who was born in the best weather using whatever features you want. Use author_births from the package.

# %%
# A plot of a 3 lines representing the hourly temperatures of Candian olympics. Use canadian_olympics from the package.

# %%
# Anything else you want with custom events not defined in the package.
